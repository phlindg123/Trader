# %%
import pandas as pd
import sys; sys.path.append("..")
from trader.data.univ import Universe
from trader.data.binance import Binance
import numpy as np

# %%
univ = Universe()
b = Binance()

# %%
tickers = [x.upper() + "USDT" for x in univ.coins.index]
tickers
# Out:
# ['BTCUSDT',
#  'LTCUSDT',
#  'BCHUSDT',
#  'XLMUSDT',
#  'XRPUSDT',
#  'ETHUSDT',
#  'SOLUSDT',
#  'ALGOUSDT',
#  'AVAXUSDT',
#  'ADAUSDT',
#  'MATICUSDT',
#  'LINKUSDT',
#  'UNIUSDT',
#  'SUSHIUSDT',
#  'AAVEUSDT',
#  'COMPUSDT',
#  'YFIUSDT',
#  'FILUSDT',
#  'MANAUSDT',
#  'AXSUSDT',
#  'DOGEUSDT',
#  'SHIBUSDT']

# %%
start = pd.to_datetime("2018-01-01")
end = pd.to_datetime("2022-07-01")
bars = b.get_bars(tickers, start, end, interval="1d")

# %%
df = univ.coins
df["Symbol"] = tickers

# %%
df
# Out:
#                  Name           Sector     Symbol
# btc           Bitcoin      Transaction    BTCUSDT
# ltc          Litecoin      Transaction    LTCUSDT
# bch      Bitcoin Cash      Transaction    BCHUSDT
# xlm    Stellar Lumens      Transaction    XLMUSDT
# xrp            Ripple      Transaction    XRPUSDT
# eth          Ethereum  Smart contracts    ETHUSDT
# sol            Solana  Smart contracts    SOLUSDT
# algo         Algorand  Smart contracts   ALGOUSDT
# avax        Avalanche  Smart contracts   AVAXUSDT
# ada           Cardano  Smart contracts    ADAUSDT
# matic         Polygon  Smart contracts  MATICUSDT
# link        Chainlink  Smart contracts   LINKUSDT
# uni           Uniswap         Exchange    UNIUSDT
# sushi       SushiSwap         Exchange  SUSHIUSDT
# aave             Aave          Lending   AAVEUSDT
# comp         Compound          Lending   COMPUSDT
# yfi     yearn.finance          Lending    YFIUSDT
# fil          Filecoin             Web3    FILUSDT
# Mana     Decentraland             Web3   MANAUSDT
# axs     Axie Infinity             Web3    AXSUSDT
# doge         Dogecoin             Meme   DOGEUSDT
# shib        Shiba Inu             Meme   SHIBUSDT

# %%
df = pd.merge(bars, df, on="Symbol")

# %%
rets = df.groupby(["CloseTime", "Sector"]).apply(lambda x: x.Return.mean()).unstack()

# %%
(1.0 + rets).cumprod().plot(logy=False)
# Out:
# <AxesSubplot:xlabel='CloseTime'>

# %%
rets.corr()
# Out:
# Sector           Exchange   Lending      Meme  Smart contracts  Transaction  \
# Sector
# Exchange         1.000000  0.730061  0.159882         0.699057     0.570197
# Lending          0.730061  1.000000  0.221677         0.756688     0.665848
# Meme             0.159882  0.221677  1.000000         0.263543     0.322866
# Smart contracts  0.699057  0.756688  0.263543         1.000000     0.837197
# Transaction      0.570197  0.665848  0.322866         0.837197     1.000000
# Web3             0.501488  0.552721  0.162425         0.648448     0.612932
#
# Sector               Web3
# Sector
# Exchange         0.501488
# Lending          0.552721
# Meme             0.162425
# Smart contracts  0.648448
# Transaction      0.612932
# Web3             1.000000

# %%
prices = bars.pivot(index="CloseTime", values="Close", columns = "Symbol")

# %%
prices
# Out:
# Symbol      AAVEUSDT  ADAUSDT  ALGOUSDT  AVAXUSDT  AXSUSDT  BCHUSDT   BTCUSDT  \
# CloseTime
# 2020-01-02       NaN  0.03348    0.2201       NaN      NaN   204.44   7200.85
# 2020-01-03       NaN  0.03269    0.2139       NaN      NaN   195.49   6965.71
# 2020-01-04       NaN  0.03417    0.2272       NaN      NaN   222.43   7344.96
# 2020-01-05       NaN  0.03434    0.2352       NaN      NaN   224.47   7354.11
# 2020-01-06       NaN  0.03460    0.2294       NaN      NaN   222.79   7358.75
# ...              ...      ...       ...       ...      ...      ...       ...
# 2022-06-28      65.5  0.48560    0.3311     19.32    15.91   111.50  20742.56
# 2022-06-29      60.1  0.46940    0.3126     18.12    15.31   103.30  20281.29
# 2022-06-30      59.9  0.46620    0.3017     17.79    14.39   104.60  20123.01
# 2022-07-01      57.0  0.45990    0.3147     16.99    14.58   103.20  19942.21
# 2022-07-02      57.2  0.45020    0.3079     16.21    14.08   101.90  19469.87
#
# Symbol      COMPUSDT  DOGEUSDT  ETHUSDT  ...  LTCUSDT  MANAUSDT  MATICUSDT  \
# CloseTime                                ...
# 2020-01-02       NaN  0.002024   130.77  ...    41.62       NaN    0.01496
# 2020-01-03       NaN  0.001995   127.19  ...    39.43       NaN    0.01467
# 2020-01-04       NaN  0.002024   134.35  ...    42.23       NaN    0.01512
# 2020-01-05       NaN  0.002058   134.20  ...    42.78       NaN    0.01484
# 2020-01-06       NaN  0.002070   135.37  ...    43.30       NaN    0.01483
# ...              ...       ...      ...  ...      ...       ...        ...
# 2022-06-28     49.70  0.072160  1192.51  ...    55.86    0.9654    0.53200
# 2022-06-29     46.66  0.066100  1144.05  ...    52.68    0.8878    0.51070
# 2022-06-30     49.73  0.069560  1100.21  ...    53.68    0.8804    0.49740
# 2022-07-01     47.48  0.066440  1071.01  ...    53.84    0.8817    0.48080
# 2022-07-02     47.72  0.066370  1073.04  ...    51.26    0.8442    0.46530
#
# Symbol      SHIBUSDT  SOLUSDT  SUSHIUSDT  UNIUSDT  XLMUSDT  XRPUSDT  YFIUSDT
# CloseTime
# 2020-01-02       NaN      NaN        NaN      NaN  0.04529  0.19305      NaN
# 2020-01-03       NaN      NaN        NaN      NaN  0.04361  0.18750      NaN
# 2020-01-04       NaN      NaN        NaN      NaN  0.04566  0.19338      NaN
# 2020-01-05       NaN      NaN        NaN      NaN  0.04565  0.19305      NaN
# 2020-01-06       NaN      NaN        NaN      NaN  0.04544  0.19453      NaN
# ...              ...      ...        ...      ...      ...      ...      ...
# 2022-06-28  0.000011    38.52      1.149     5.33  0.11910  0.35370  6218.14
# 2022-06-29  0.000010    35.35      1.083     4.92  0.11430  0.33750  5650.84
# 2022-06-30  0.000010    34.05      1.052     5.11  0.11010  0.32960  5604.23
# 2022-07-01  0.000010    33.76      0.990     5.00  0.11230  0.33210  5419.10
# 2022-07-02  0.000010    33.11      0.979     4.87  0.11070  0.31290  5425.61
#
# [913 rows x 22 columns]
