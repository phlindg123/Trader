# %%
import pandas as pd
import numpy as np
import sys; sys.path.append("..")
from trader.data.binance import Binance
import copy

# %%
#b = Binance(test=False)

# %%
#bars = b.get_bars(["BTCUSDT", "ETHUSDT", "DOGEUSDT", "LINKUSDT"], pd.to_datetime("2022-06-15"), pd.to_datetime("2022-06-20"), interval="1h")
bars = pd.read_csv("daily.csv")
bars = bars[bars.Symbol.isin(["BTCUSDT", "ETHUSDT", "LINKUSDT", "DOGEUSDT", "ADAUSDT"])]
bars.CloseTime = pd.to_datetime(bars.CloseTime)
bars.head()
# Out:
#        OpenTime     Open     High      Low    Close       Volume  CloseTime  \
# 697  2018-04-17  0.25551  0.28800  0.23983  0.24260  67462293.24 2018-04-18
# 698  2018-04-18  0.24260  0.26460  0.24201  0.26200  31328095.79 2018-04-19
# 699  2018-04-19  0.26199  0.27500  0.25777  0.27004  50859980.22 2018-04-20
# 700  2018-04-20  0.27004  0.30442  0.26648  0.30108  71084276.49 2018-04-21
# 701  2018-04-21  0.30161  0.30700  0.26509  0.28668  92719842.91 2018-04-22
#
#       QuoteVolume  NumTrades  TakerBaseVolume  TakerQuoteVolue    Return  \
# 697  1.741182e+07      42568      28228665.39     7.281513e+06       NaN
# 698  7.922134e+06      21684      15082512.84     3.818069e+06  0.079967
# 699  1.360991e+07      32600      23934593.69     6.408750e+06  0.030687
# 700  2.027089e+07      46506      35262790.18     1.004084e+07  0.114946
# 701  2.653939e+07      55256      43517191.79     1.241365e+07 -0.047828
#
#       Symbol
# 697  ADAUSDT
# 698  ADAUSDT
# 699  ADAUSDT
# ...

# %%
class Pair:
    def __init__(self, base, quote):
        self.base = base
        self.quote = quote
        self.symbol = base + quote

# %%
class Position:
    def __init__(self, symbol, base_amt=None, fx=None):
        self.symbol = symbol
        self.base_amt = base_amt
        self.fx = fx
        self.quote_amt = base_amt * fx
    
    def update(self, fx=None, base_amt=None, quote_amt=None):
        old_quote_amt = self.quote_amt
        self.fx = fx
        if base_amt != None:
            self.base_amt = base_amt
        if quote_

# %%
class Data:
    def __init__(self, bars, window_size=30):
        self.bars = bars
        self.window_size = window_size
        
    def get(self, date, freq="1d"):
        prev_idx = date - pd.Timedelta(freq)*self.window_size
        df_ = self.bars[(self.bars.CloseTime > prev_idx) & (self.bars.CloseTime <= date)]
        return df_

# %%
class Portfolio:
    def __init__(self, pairs, initial_balance = {"USDT" : 100.0}):
        self.pairs = pairs
        self.initial_balance = initial_balance
        self.setup()
        
    def setup(self):
        bases = list(set([x.base for x in self.pairs.values()]))
        quotes = list(set([x.quote for x in self.pairs.values()]))
        currs = bases + quotes
        self.holdings = {k:0 for k in currs}
        self.holdings.update(self.initial_balance)
        self.positions = {k : Position(k, 0, 1) for k in self.pairs.keys()}
    
    def order(self, symbol, fx, amount):
        pair = self.pairs[symbol]
        base_amt = amount
        quote_amt = amount * fx * (-1)
        if quote_amt < 0: #selling quote, buying base
            if self.holdings[pair.quote] < abs(quote_amt):
                print(f"Not enough {pair.quote} for {pair.symbol} order")
                return
        elif base_amt < 0:
            if self.holdings[pair.base] < abs(base_amt):
                print(f"Not enough {pair.base} for {pair.symbol} order")
                return
        
        self.holdings[pair.base] += base_amt
        self.holdings[pair.quote] += quote_amt
        self.positions[pair.symbol] = Position(symbol, base_amt=base_amt, fx=fx)
        
    def update(self, prices):
        #Bara base updateras här
        for symbol, pair in self.pairs.items():
            self.positions[symbol].update(prices[symbol])
    
    
    
    def get_holdings(self):
        return pd.Series(self.holdings)
    
    def get_positions(self):
        return pd.Series({k : v.base_amt for k, v in self.positions.items()})
    
    def has_position(self, symbol):
        return self.positions[symbol].base_amt != 0.0
    
    def get_position(self, symbol):
        return self.positions[symbol]
    
    def get_holding(self, curr):
        return self.holdings[curr]

# %%
p = Portfolio(pairs)

# %%
p.holdings
# Out:
# {'DOGE': 0, 'LINK': 0, 'BTC': 0, 'ETH': 0, 'ADA': 0, 'USDT': 100.0}

# %%
p.order("BTCUSDT", 10, 2)

# %%
p.holdings
# Out:
# {'DOGE': 0, 'LINK': 0, 'BTC': 2, 'ETH': 0, 'ADA': 0, 'USDT': 80.0}

# %%
def cp_meanrev(price, window, sigma, trade_on=0):
    if price.shape[0] < window:
        return None
    mean = price.iloc[-window:].mean()
    std = price.diff().iloc[-window:].std()
    if (price.iloc[-1] < mean - std*sigma) and (trade_on == 0):
        return 1
    elif (price.iloc[-1] > mean) and (trade_on > 0):
        return 0
    else:
        return trade_on

# %%
def cp_trend(price, window):
    if price.shape[0] < window*8:
        return None
    r1 = np.sign(price.iloc[-1]/price.iloc[-window*8] -1)
    r2 = np.sign(price.iloc[-1]/price.iloc[-window*4] -1)
    r3 = np.sign(price.iloc[-1]/price.iloc[-window] -1)
    signal = (r1+r2+r3)/3.0
    if signal > 0:
        return 1
    else:
        return 0
    return signal

# %%
class Backtest:
    def __init__(self, pairs, data, index, state={}):
        self.pairs = pairs
        self.symbols = list(pairs.keys())
        self.data = data
        self.index = index
        self.state = state
        self.portfolio = Portfolio(pairs)
        self.states = []
        
        
    def initialize(self):
        pass
    
    def get_fx(self, symbol):
        #TODO: implement
        return 1
        
    def order(self, symbol, quote_size=0, base_size=0, fx=None):
        #TODO: ADD FEE
        base = symbol[:3] #NEED TO FIX, CAN BE MORE THAN 3.
        quote = symbol[3:] #NEED TO FIX
        if fx is None:
            fx = self.get_fx(symbol)
        if (quote_size == 0) & (base_size != 0):
            quote_size = base_size * fx
        elif (quote_size != 0) & (base_size == 0):
            base_size = quote_size / fx
        self.state["positions"][base] += base_size
        self.state["positions"][quote] -= quote_size
    
    def step(self, t):
        self.state["date"] = t
        bars = data.get(t)
        prices = bars.pivot(index="CloseTime", columns = "Symbol", values="Close")
        for symbol in self.symbols:
            price = prices[symbol]
            last_price = price.iloc[-1]
            signal = cp_trend(price[:-1], window=4)
            size = self.portfolio.get_holding("USDT") / len(self.symbols) / last_price
            if (signal == 1) and (not self.portfolio.has_position(symbol)):
                self.portfolio.order(symbol, last_price, size)
            elif (signal == 0) and self.portfolio.has_position(symbol):
                size = self.portfolio.get_position(symbol).base_amt
                self.portfolio.order(symbol, last_price, -size)
        self.portfolio.update(prices.iloc[-1])
        self.state["holdings"] = self.portfolio.get_holdings()
        self.state["positions"] = self.portfolio.get_positions()
        
            
    
    def run(self):
        for t in self.index:
            self.step(t)
            self.states.append(copy.deepcopy(self.state))

# %%
btc = Pair("BTC", "USDT")
eth = Pair("ETH", "USDT")
link = Pair("LINK", "USDT")
ada = Pair("ADA", "USDT")
doge = Pair("DOGE", "USDT")
pairs = [btc, eth, link, ada, doge]
pairs = {x.symbol : x for x in pairs}

# %%
data = Data(bars, window_size=120)
index = pd.date_range("2022-06-01", "2022-08-01")
bt = Backtest(pairs, data, index)

# %%
bt.run()
# Out:
# Not enough BTC for BTCUSDT order
# Not enough LINK for LINKUSDT order
# Not enough LINK for LINKUSDT order
# Not enough ADA for ADAUSDT order
# Not enough LINK for LINKUSDT order
# Not enough LINK for LINKUSDT order
# Not enough ADA for ADAUSDT order
# Not enough LINK for LINKUSDT order
# Not enough DOGE for DOGEUSDT order
# Not enough LINK for LINKUSDT order
# Not enough ADA for ADAUSDT order
# Not enough ADA for ADAUSDT order
# Not enough ADA for ADAUSDT order
# Not enough BTC for BTCUSDT order
# Not enough BTC for BTCUSDT order
# Not enough BTC for BTCUSDT order
# Not enough LINK for LINKUSDT order
# Not enough ADA for ADAUSDT order
# Not enough LINK for LINKUSDT order
# Not enough ADA for ADAUSDT order

# %%
bt.states
# Out:
# [{'date': Timestamp('2022-06-01 00:00:00', freq='D'),
#   'holdings': DOGE     0.000000
#   LINK     0.000000
#   BTC      0.000629
#   ETH      0.000000
#   ADA      0.000000
#   USDT    80.000000
#   dtype: float64,
#   'positions': BTCUSDT     0.000629
#   ETHUSDT     0.000000
#   LINKUSDT    0.000000
#   ADAUSDT     0.000000
#   DOGEUSDT    0.000000
#   dtype: float64},
#  {'date': Timestamp('2022-06-02 00:00:00', freq='D'),
#   'holdings': DOGE     0.000000
#   LINK     2.308802
#   BTC      0.000589
#   ETH      0.000000
#   ADA     23.205221
#   USDT    51.200000
#   dtype: float64,
#   'positions': BTCUSDT      0.000629
#   ETHUSDT      0.000000
#   LINKUSDT     2.308802
#   ADAUSDT     23.205221
#   DOGEUSDT     0.000000
#   dtype: float64},
#  {'date': Timestamp('2022-06-03 00:00:00', freq='D'),
#   'holdings': DOGE     0.000000
#   LINK    -2.308802
#   BTC      0.000643
#   ETH      0.000000
#   ADA    -23.205221
#   USDT    81.424074
#   dtype: float64,
# ...

# %%
holds = []
poss = []
for state in bt.states:
    date = state["date"]
    holdings = pd.Series(state["holdings"], name=date)
    positions = pd.Series(state["positions"], name=date)
    holds.append(holdings)
    poss.append(positions)
holds = pd.DataFrame(holds)
poss = pd.DataFrame(poss)

# %%
poss.plot()
# Out:
# <AxesSubplot:>

# %%
holds.plot()
# Out:
# <AxesSubplot:>

# %%
state
# Out:
# {'date': Timestamp('2022-06-01 00:00:00', freq='D'),
#  'holdings': DOGE     0.000000
#  LINK     0.000000
#  BTC      0.000629
#  ETH      0.000000
#  ADA      0.000000
#  USDT    80.000000
#  dtype: float64,
#  'positions': BTCUSDT     0.000629
#  ETHUSDT     0.000000
#  LINKUSDT    0.000000
#  ADAUSDT     0.000000
#  DOGEUSDT    0.000000
#  dtype: float64}

# %%
# class Backtest:
#     def __init__(self, pairs, data, index, portfolio, state={}):
#         self.data = data
#         self.index = index
#         self.state = state
#         self.states = []
        
        
#     def initialize(self):
#         symbols = list(self.data.keys())
#         currs = []
#         for s in symbols:
#             c1, c2 = s[:3], s[3:]
#             currs.extend([c1,c2])
#         currs = np.unique(currs)
#         self.state["positions"] = {k:0 for k in currs}
#         self.state["positions"]["USDT"] = 100
#         self.state["trades_on"] = {k:0 for k in symbols}
#         self.state["prices"] = {k : data[k].Close.loc[self.index[0]] for k in symbols}
#         self.state["date"] = self.index[0]
    
#     def get_fx(self, symbol):
#         #TODO: implement
#         return 1
        
#     def order(self, symbol, quote_size=0, base_size=0, fx=None):
#         #TODO: ADD FEE
#         base = symbol[:3] #NEED TO FIX, CAN BE MORE THAN 3.
#         quote = symbol[3:] #NEED TO FIX
#         if fx is None:
#             fx = self.get_fx(symbol)
#         if (quote_size == 0) & (base_size != 0):
#             quote_size = base_size * fx
#         elif (quote_size != 0) & (base_size == 0):
#             base_size = quote_size / fx
#         self.state["positions"][base] += base_size
#         self.state["positions"][quote] -= quote_size
    
#     def step(self, t):
#         self.state["date"] = t
#         for s in self.data.keys():
#             price = self.data[s].Close.loc[:t]
#             self.state["prices"][s] = price.iloc[-1]
#             trade_on = self.state["trades_on"][s]
#             #signal = cp_meanrev(price, 30, 1.5, trade_on)
#             signal = cp_trend(price, 5)
#             if trade_on != signal:
#                 quote_size = 0.5 * self.state["positions"][s[3:]]
#                 self.order(s, quote_size=quote_size, fx = price.iloc[-1])
#                 self.state["trades_on"][s] = signal
#         self.states.append(copy.deepcopy(self.state))
            
            
    
#     def run(self):
#         for i,t in enumerate(self.index):
#             if i < 30:
#                 continue
#             self.step(t)

# %%
bt = Backtest(data, index)
bt.initialize()

# %%
bt.run()

# %%
pd.DataFrame(bt.state)
# Out:
#          positions  trades_on    prices       date
# BTC       0.003169        NaN       NaN 2022-06-20
# ETH       0.030795        NaN       NaN 2022-06-20
# USDT      0.000381        NaN       NaN 2022-06-20
# BTCUSDT        NaN        1.0  20574.00 2022-06-20
# ETHUSDT        NaN        1.0   1128.53 2022-06-20

# %%
positions = {}
trades = {}
prices = {}
for state in bt.states:
    date = state["date"]
    positions[date] = state["positions"]
    trades[date] = state["trades_on"]
    prices[date] = state["prices"]

# %%
pd.DataFrame(positions).T
# Out:
#                           BTC       ETH        USDT
# 2022-06-16 18:00:00  0.000000  0.000000  100.000000
# 2022-06-16 19:00:00  0.000000  0.000000  100.000000
# 2022-06-16 20:00:00  0.000000  0.000000  100.000000
# 2022-06-16 21:00:00  0.000000  0.000000  100.000000
# 2022-06-16 22:00:00  0.000000  0.000000  100.000000
# ...                       ...       ...         ...
# 2022-06-19 20:00:00  0.003169  0.030795    0.000381
# 2022-06-19 21:00:00  0.003169  0.030795    0.000381
# 2022-06-19 22:00:00  0.003169  0.030795    0.000381
# 2022-06-19 23:00:00  0.003169  0.030795    0.000381
# 2022-06-20 00:00:00  0.003169  0.030795    0.000381
#
# [79 rows x 3 columns]

# %%
pd.DataFrame(prices).T.plot()
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame(positions).T.plot(secondary_y="USDT")
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame(prices).T.join(pd.DataFrame(trades).T, rsuffix="_")[["BTCUSDT", "BTCUSDT_"]].plot(secondary_y = "BTCUSDT_")
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame(prices).T.join(pd.DataFrame(trades).T, rsuffix="_")[["ETHUSDT", "ETHUSDT_"]].plot(secondary_y = "ETHUSDT_")
# Out:
# <AxesSubplot:>
