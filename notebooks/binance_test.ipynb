# %% [markdown]
# ## Notes
#     - Which room is best?
#         - Bottom one seem to be bottom?
#         - Would all rooms cost the same?
#         - Will we be switching around if all pay the same?
#     - Would I be on the contract?
#         - Need to see it anyhow

# %%
import sys;sys.path.append("..")
from trader.data.binance import Binance
from trader.data.univ import Universe
import pandas as pd
import numpy as np
from binance.enums import ORDER_TYPE_MARKET, SIDE_BUY, SIDE_SELL

# %%
univ = Universe()
yay = univ.coins.index.to_list()
yay = [x.upper() + "USDT" for x in yay]

# %%
b = Binance(test=True)

# %%
acc = b.get_account()

# %%
acc
# Out:
# asset
# BNB       1000.00000
# BTC          0.99500
# BUSD     10000.00000
# ETH        100.00000
# LTC        500.00000
# TRX     500000.00000
# USDT     10113.56745
# XRP      50000.00000
# Name: free, dtype: float64

# %%
sym = b.client.get_symbol_info("BNBUSDT")

# %%
sym
# Out:
# {'symbol': 'BNBUSDT',
#  'status': 'TRADING',
#  'baseAsset': 'BNB',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'USDT',
#  'quotePrecision': 8,
#  'quoteAssetPrecision': 8,
#  'baseCommissionPrecision': 8,
#  'quoteCommissionPrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'ocoAllowed': True,
#  'quoteOrderQtyMarketAllowed': True,
#  'allowTrailingStop': True,
#  'cancelReplaceAllowed': True,
#  'isSpotTradingAllowed': True,
#  'isMarginTradingAllowed': False,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.01000000',
#    'maxPrice': '10000.00000000',
#    'tickSize': '0.01000000'},
#   {'filterType': 'PERCENT_PRICE',
#    'multiplierUp': '5',
#    'multiplierDown': '0.2',
#    'avgPriceMins': 1},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.01000000',
#    'maxQty': '9000.00000000',
#    'stepSize': '0.01000000'},
#   {'filterType': 'MIN_NOTIONAL',
# ...

# %%
filters': [{'filterType': 'PRICE_FILTER',
   'minPrice': '0.10000000',
   'maxPrice': '100000.00000000',
   'tickSize': '0.10000000'},

# %%
b.create_market_order("BNBUSDT", "s", 0.0005, test=True)
# Out:
# ---------------------------------------------------------------------------
# BinanceAPIException                       Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 b.create_market_order("BNBUSDT", "s", 0.0005, test=True)
#
# File ~\Documents\Kod\Trader\notebooks\..\trader\data\binance.py:24, in Binance.create_market_order(self, symbol, side, quantity, test)
#      22     side = enums.SIDE_SELL
#      23 if test:
# ---> 24     return self.client.create_test_order(symbol=symbol, side=side, quantity=quantity, type = enums.ORDER_TYPE_MARKET)
#      25 return self.client.create_order(symbol=symbol, side=side, quantity=quantity, type = enums.ORDER_TYPE_MARKET)
#
# File ~\anaconda3\envs\Trader\lib\site-packages\binance\client.py:1775, in Client.create_test_order(self, **params)
#    1739 def create_test_order(self, **params):
# ...

# %%
b.client.get_account()
# Out:
# {'makerCommission': 0,
#  'takerCommission': 0,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'canTrade': True,
#  'canWithdraw': False,
#  'canDeposit': False,
#  'updateTime': 1658688137113,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BNB',
#    'free': '1000.00000000',
#    'locked': '0.00000000'},
#   {'asset': 'BTC', 'free': '0.99500000', 'locked': '0.00000000'},
#   {'asset': 'BUSD', 'free': '10000.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '100.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '500.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRX', 'free': '500000.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDT', 'free': '10113.56745000', 'locked': '0.00000000'},
#   {'asset': 'XRP', 'free': '50000.00000000', 'locked': '0.00000000'}],
#  'permissions': ['SPOT']}

# %%
start = pd.to_datetime("2022-06-01")
end = pd.to_datetime("today").floor("D")
symbol = "BTCUSDT"
interval = "1h"
#klines = b.client.get_historical_klines(symbol=symbol, interval=interval,limit=1000, start_str = str(int(start.timestamp())), end_str=str(int(end.timestamp())))

# %%
spot = b.get_bars("BTCUSDT", start, end, "1h", "SPOT")
fut = b.get_bars("BTCUSDT", start, end, "1h", "FUTURE")

# %%
spot
# Out:
#                OpenTime      Open      High       Low     Close      Volume  \
# 0   2022-06-01 01:00:00  31936.53  31947.26  31836.99  31926.12  1280.94083
# 1   2022-06-01 02:00:00  31926.13  31926.13  31731.01  31806.72  1647.05696
# 2   2022-06-01 03:00:00  31806.71  31806.72  31614.01  31627.30  1937.06614
# 3   2022-06-01 04:00:00  31627.29  31670.00  31371.45  31566.60  2528.78791
# 4   2022-06-01 05:00:00  31566.60  31626.93  31445.76  31622.28  1293.69241
# ..                  ...       ...       ...       ...       ...         ...
# 692 2022-06-29 21:00:00  20224.04  20357.06  20196.80  20295.35  1443.38271
# 693 2022-06-29 22:00:00  20295.35  20326.12  20151.77  20213.64  5882.17945
# 694 2022-06-29 23:00:00  20213.64  20218.89  20052.74  20123.01  2047.52726
# 695 2022-06-30 00:00:00  20123.00  20179.08  20011.17  20037.92  2386.15679
# 696 2022-06-30 01:00:00  20037.91  20084.99  19951.08  20018.44  2705.05313
#
# ...
